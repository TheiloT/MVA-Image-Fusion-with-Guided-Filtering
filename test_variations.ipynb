# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

from src.utils import *
from src.fusion import *

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Testing on other multi-focus images

# %%
golf1 = plt.imread("dataset/multi-focus/color/c_09_1.tif")
golf2 = plt.imread("dataset/multi-focus/color/c_09_2.tif")
show_images(golf1, golf2, "original", "original")

# %% [markdown]
# # OpenCV

# %%
fused_golf = fuse_images(golf1, golf2, verbose=True)
# Out:
# Computing base and detail layers...
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 fused_golf = fuse_images(golf1, golf2, verbose=True)
#
# File d:\Etudes\Ponts et chaussees\MVA\Cours\Introduction imagerie numerique\MVA-Image-Fusion-with-Guided-Filtering\src\fusion.py:142, in fuse_images(im1, im2, average_filter_size, laplacian_kernel_size, gaussian_filter_sigma, gaussian_filter_radius, local_average_size, r1, eps1, r2, eps2, verbose)
#     140 if verbose:
#     141     print("Computing base and detail layers...")
# --> 142 base1, detail1 = get_base_detail_layers(im1, average_filter_size)
#     143 base2, detail2 = get_base_detail_layers(im2, average_filter_size)
#     144 if verbose:
#
# ...

# %%
#Zooming on details
top_left = [150,150]
plt.imshow(fused_golf[top_left[0]:top_left[0]+200, top_left[1]:top_left[1]+200, :])
plt.title("Zoom on detail")
plt.axis('off')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (-0.5, 199.5, 199.5, -0.5)

# %%
# Parameters
average_filter_size = 31

base1, detail1 = get_base_detail_layers(golf1, average_filter_size)
base2, detail2 = get_base_detail_layers(golf2, average_filter_size)

# Plot results
show_images(base1, base2, 'base', 'base')
show_images(detail1, detail2, 'details', 'details')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
zoom_on_detail(base1)

# %% [markdown]
# # Our version

# %%
fused_golf = fuse_images(golf1, golf2, verbose=True)
# Out:
# Computing base and detail layers...
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Computing saliency maps...
# Computing weight maps...
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Fusing layers...
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Fused image:

# %%
# Parameters
average_filter_size = 31

base1, detail1 = get_base_detail_layers(golf1, average_filter_size)
base2, detail2 = get_base_detail_layers(golf2, average_filter_size)

# Plot results
show_images(base1, base2, 'base', 'base')
show_images(detail1, detail2, 'details', 'details')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
zoom_on_detail(base1)

# %% [markdown]
# # Metrics
